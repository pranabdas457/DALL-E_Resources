# %%
! pip install min-dalle -q
# Out:
#      |████████████████████████████████| 240 kB 5.0 MB/s
#   Building wheel for min-dalle (setup.py) ... done
#   Building wheel for emoji (setup.py) ... done

# %%
from min_dalle import MinDalle

model = MinDalle(is_mega=True, is_reusable=True)
# Out:
# using device cuda
# downloading tokenizer params
# intializing TextTokenizer
# downloading encoder params
# initializing DalleBartEncoder
# downloading decoder params
# initializing DalleBartDecoder
# downloading detokenizer params
# initializing VQGanDetokenizer

# %%
# %%time

text = "kung fu panda" 
seed = 10 
grid_size = 3

display(model.generate_image(text, seed, grid_size))
# Out:
# <PIL.Image.Image image mode=RGB size=768x768 at 0x7F0C014D9CD0>
# CPU times: user 52 s, sys: 1.4 s, total: 53.4 s
# Wall time: 53.3 s
